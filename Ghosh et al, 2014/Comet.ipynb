# %% [markdown]
# ## Modelling

# %%
from __future__ import division
from pyomo.environ import *
from math import pi as PI
from math import cos as COS
from math import sin as SIN

# %%
m = 10  # number of grid points
K = 3   # problem dimensionality

# %%
def solve(beta):
    model = ConcreteModel()

    # generic variables
    model.z = Var(domain=Reals, initialize=0.05) # init with z=0 fails on 1st step. refer article
    model.OBJ = Objective(expr = model.z, sense=minimize)

    # problem specific variables
    model.x1 = Var(domain=Reals, bounds=(1,3.5))
    model.x2 = Var(domain=Reals, bounds=(-2,2))
    model.x3 = Var(domain=Reals)
    f = ((1+model.x3)*((model.x1**3)*(model.x2**2)-10*model.x1-4*model.x2),
         (1+model.x3)*((model.x1**3)*(model.x2**2)-10*model.x1+4*model.x2),
         3*(1+model.x3)*(model.x2**2))     # multicriterion objective function

    # add generic beta constraints
    model.DIM = RangeSet(0,K-1)
    def beta_constraint(model, i):
        return model.z*beta[i] >= f[i]
    model.beta_const = Constraint(model.DIM,rule=beta_constraint)

    # no problem specific feasibility constraints
    
    # model.pprint()
    
    # solve on NEOS solver 
    solver_manager = SolverManagerFactory('neos')
    results = solver_manager.solve(model, opt='knitro')
    
    print(results)
    
    if results.solver.status == SolverStatus.ok and results.solver.termination_condition == TerminationCondition.optimal:
        return value(model.OBJ)
    elif results.solver.termination_condition == TerminationCondition.infeasible:
        return 0
    else:
        return 0

# %%
# do the simulation
points = []

for i in range(1,m): # 0,m exlcusive
    theta1 = (i*PI)/(2*m)
    m2 = round(m*SIN(theta1))
    for i2 in range(1,m2): # 0,m2 exlcusive
        theta2 = (i2*PI)/(2*m2)
        beta = (COS(theta1), COS(theta2)*SIN(theta1),SIN(theta2)*SIN(theta1))
        tmp = solve(beta)
        print("iter (%d,%d): z=%f" % (i,i2,tmp))
        points.append((tmp,beta))
# Out:
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.7243800084094365e-08; feasibility error 1.91e-09; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (1,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.676161078805136e-09; feasibility error 2.59e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (2,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -2.2325265570332104e-10; feasibility error 5.97e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (2,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -2.2108943528989977e-09; feasibility error 3.1e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (3,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -2.0778448161095118e-10; feasibility error 5.54e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (3,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -8.114990062421597e-11; feasibility error 2.98e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (3,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -3.94807902066305e-11; feasibility error 1.7e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (3,4): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.3127123749635334e-09; feasibility error 2e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (4,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.5956731730117617e-10; feasibility error 4.69e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (4,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -4.6252814731623885e-11; feasibility error 1.92e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (4,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -3.2181815943613424e-12; feasibility error 1.64e-12; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (4,4): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.4908914220739748e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (4,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.050365331763456e-09; feasibility error 1.65e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.4363332252949655e-10; feasibility error 4.41e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -3.249498145636315e-11; feasibility error 1.43e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.1780761627842444e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,4): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 3.275637108960693e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 4.2265583702159594e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (5,6): z=0.000000
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.0992510517120093e-09; feasibility error 1.73e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.3892628164382339e-10; feasibility error 4.3e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -2.8312928832400136e-11; feasibility error 1.27e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.730170071623714e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,4): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 4.008309113780931e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 5.1952453336682775e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,6): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 5.768214068076155e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (6,7): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.3137567033937579e-09; feasibility error 2.03e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.4401261459767834e-10; feasibility error 4.39e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -2.995712601662243e-11; feasibility error 1.33e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.7515790350886934e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,4): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 4.1869383380607454e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 5.526664519129069e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,6): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 6.259449676709039e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,7): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 6.625777831941236e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (7,8): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.9193378314162905e-09; feasibility error 2.86e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.6225422091507984e-10; feasibility error 4.77e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -3.763242053441992e-11; feasibility error 1.62e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,3): z=-0.000000
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.3271911598634404e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,4): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 3.977228600095172e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 5.49125859248053e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,6): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 6.358376672060766e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,7): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 6.847592457891968e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,8): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 7.095053700393815e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (8,9): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.9676454192148077e-09; feasibility error 3.04e-10; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,1): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -1.520694196424617e-10; feasibility error 4.64e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,2): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective -3.048794461511391e-11; feasibility error 1.37e-11; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,3): z=-0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 1.8487616845219327e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,4): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 4.386470878793885e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,5): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 5.834206742073499e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,6): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 6.647837749840005e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,7): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 7.094787028714569e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,8): z=0.000000
#
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 3
#   Number of variables: 4
#   Sense: unknown
# Solver:
# - Status: ok
#   Message: Knitro 11.1.0\x3a Locally optimal or satisfactory solution.; objective 7.316397932208881e-11; feasibility error 0; 3 iterations; 5 function evaluations
#   Termination condition: optimal
#   Id: 0
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# iter (9,9): z=0.000000

# %% [markdown]
# ## Analysing result

# %%
points
# Out:
# [(-1.7243800084094365e-08,
#   (0.9876883405951378, 0.11061587104123716, 0.11061587104123716)),
#  (-1.676161078805136e-09,
#   (0.9510565162951535, 0.2676165673298174, 0.15450849718747367)),
#  (-2.2325265570332104e-10,
#   (0.9510565162951535, 0.15450849718747373, 0.2676165673298174)),
#  (-2.2108943528989977e-09,
#   (0.8910065241883679, 0.43177062311338915, 0.14029077970429507)),
#  (-2.0778448161095118e-10,
#   (0.8910065241883679, 0.3672860295740685, 0.26684892042779546)),
#  (-8.114990062421597e-11,
#   (0.8910065241883679, 0.26684892042779546, 0.3672860295740685)),
#  (-3.94807902066305e-11,
#   (0.8910065241883679, 0.1402907797042951, 0.43177062311338915)),
#  (-1.3127123749635334e-09,
#   (0.8090169943749475, 0.5677569555011356, 0.15213001772368215)),
#  (-1.5956731730117617e-10,
#   (0.8090169943749475, 0.5090369604551273, 0.2938926261462365)),
#  (-4.6252814731623885e-11,
#   (0.8090169943749475, 0.41562693777745346, 0.41562693777745346)),
#  (-3.2181815943613424e-12,
#   (0.8090169943749475, 0.2938926261462366, 0.5090369604551271)),
#  (1.4908914220739748e-11,
#   (0.8090169943749475, 0.15213001772368215, 0.5677569555011356)),
#  (-1.050365331763456e-09,
#   (0.7071067811865476, 0.6893781378718105, 0.1573460613564738)),
#  (-1.4363332252949655e-10,
#   (0.7071067811865476, 0.6370811961317674, 0.30680213417660024)),
#  (-3.249498145636315e-11,
#   (0.7071067811865476, 0.5528383429982753, 0.4408738668949674)),
#  (1.1780761627842444e-11,
#   (0.7071067811865476, 0.44087386689496744, 0.5528383429982753)),
#  (3.275637108960693e-11,
#   (0.7071067811865476, 0.3068021341766003, 0.6370811961317674)),
#  (4.2265583702159594e-11,
#   (0.7071067811865476, 0.15734606135647383, 0.6893781378718105)),
#  (-1.0992510517120093e-09,
#   (0.5877852522924731, 0.7934719596790115, 0.1578313859491287)),
#  (-1.3892628164382339e-10,
#   (0.5877852522924731, 0.7474342425568128, 0.30959740024909344)),
#  (-2.8312928832400136e-11,
#   (0.5877852522924731, 0.672673046659108, 0.44946576008170774)),
#  (1.730170071623714e-11,
#   (0.5877852522924731, 0.5720614028176844, 0.5720614028176844)),
#  (4.008309113780931e-11,
#   (0.5877852522924731, 0.44946576008170785, 0.672673046659108)),
#  (5.1952453336682775e-11,
#   (0.5877852522924731, 0.3095974002490935, 0.7474342425568128)),
#  (5.768214068076155e-11,
#   (0.5877852522924731, 0.1578313859491288, 0.7934719596790115)),
#  (-1.3137567033937579e-09,
#   (0.4539904997395468, 0.8774701330051641, 0.15472165921465575)),
#  (-1.4401261459767834e-10,
#   (0.4539904997395468, 0.8372722558519102, 0.30474217910701146)),
#  (-2.995712601662243e-11,
#   (0.4539904997395468, 0.7716342848848005, 0.44550326209418384)),
#  (1.7515790350886934e-11,
#   (0.4539904997395468, 0.6825505966372544, 0.5727279538981526)),
#  (4.1869383380607454e-11,
#   (0.4539904997395468, 0.5727279538981527, 0.6825505966372544)),
#  (5.526664519129069e-11,
#   (0.4539904997395468, 0.445503262094184, 0.7716342848848003)),
#  (6.259449676709039e-11,
#   (0.4539904997395468, 0.30474217910701157, 0.8372722558519101)),
#  (6.625777831941236e-11,
#   (0.4539904997395468, 0.15472165921465583, 0.8774701330051641)),
#  (-1.9193378314162905e-09,
#   (0.30901699437494745, 0.9393474323917528, 0.14877801734965795)),
#  (-1.6225422091507984e-10,
#   (0.30901699437494745, 0.9045084971874736, 0.2938926261462365)),
#  (-3.763242053441992e-11,
#   (0.30901699437494745, 0.8473975608908426, 0.43177062311338915)),
#  (1.3271911598634404e-11,
#   (0.30901699437494745, 0.7694208842938134, 0.5590169943749475)),
#  (3.977228600095172e-11,
#   (0.30901699437494745, 0.6724985119639574, 0.6724985119639574)),
#  (5.49125859248053e-11,
#   (0.30901699437494745, 0.5590169943749475, 0.7694208842938134)),
#  (6.358376672060766e-11,
#   (0.30901699437494745, 0.4317706231133892, 0.8473975608908425)),
#  (6.847592457891968e-11,
#   (0.30901699437494745, 0.29389262614623657, 0.9045084971874736)),
#  (7.095053700393815e-11,
#   (0.30901699437494745, 0.148778017349658, 0.9393474323917528)),
#  (-1.9676454192148077e-09,
#   (0.15643446504023092, 0.9755282581475768, 0.15450849718747373)),
#  (-1.520694196424617e-10,
#   (0.15643446504023092, 0.9393474323917528, 0.3052124823898888)),
#  (-3.048794461511391e-11,
#   (0.15643446504023092, 0.8800367553350505, 0.44840112333371024)),
#  (1.8487616845219327e-11,
#   (0.15643446504023092, 0.7990566526874577, 0.5805486404630472)),
#  (4.386470878793885e-11,
#   (0.15643446504023092, 0.6984011233337104, 0.6984011233337104)),
#  (5.834206742073499e-11,
#   (0.15643446504023092, 0.5805486404630472, 0.7990566526874577)),
#  (6.647837749840005e-11,
#   (0.15643446504023092, 0.4484011233337103, 0.8800367553350504)),
#  (7.094787028714569e-11,
#   (0.15643446504023092, 0.30521248238988885, 0.9393474323917528)),
#  (7.316397932208881e-11,
#   (0.15643446504023092, 0.15450849718747378, 0.9755282581475768))]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as pat

fig, ax = plt.subplots()
ax.set_aspect('equal')

# drawing the circle
circle = pat.Wedge((0.5,0.5), 0.707,-45,135,color='grey')
circle.set_clip_on(False)
circle.set_alpha(0.3)
ax.add_artist(circle)

for z, beta in points:
    if z > 0: # coz the function is symmetric
        plt.scatter(z*beta[0], z*beta[1], color='black')
        plt.scatter(z*beta[1], z*beta[0], color='black')
plt.show()
